# %%
from imageai.Detection import VideoObjectDetection
import os
import time
import torch

# %%
def forFrame(frame_number, output_array, output_count):
    print("FOR FRAME " , frame_number)
    print("Output for each object : ", output_array)
    print("Output count for unique objects : ", output_count)
    print("------------END OF A FRAME --------------")

def forSeconds(second_number, output_arrays, count_arrays, average_output_count):
    print("SECOND : ", second_number)
    print("Array for the outputs of each frame ", output_arrays)
    print("Array for output count for unique objects in each frame : ", count_arrays)
    print("Output average count for unique objects in the last second: ", average_output_count)
    print("------------END OF A SECOND --------------")

def forMinute(minute_number, output_arrays, count_arrays, average_output_count):
    print("MINUTE : ", minute_number)
    print("Array for the outputs of each frame ", output_arrays)
    print("Array for output count for unique objects in each frame : ", count_arrays)
    print("Output average count for unique objects in the last minute: ", average_output_count)
    print("------------END OF A MINUTE --------------")

# %%
# Start timing
start_time = time.time()

# Set the execution path
execution_path = os.getcwd()

video_detector = VideoObjectDetection()
video_detector.setModelTypeAsTinyYOLOv3()
video_detector.setModelPath(os.path.join(execution_path, "/models/tiny-yolov3.pt"))
video_detector.loadModel()

video_detector.detectObjectsFromVideo(
    input_file_path=os.path.join(execution_path, "/videos/jen.mp4"),
    output_file_path=os.path.join(execution_path, "Jenuvin_Jojy"),
    frames_per_second=10,
    per_second_function=forSeconds,
    per_frame_function=forFrame,
    per_minute_function=forMinute,
    minimum_percentage_probability=30
)
# End timing and calculate the duration
end_time = time.time()
execution_duration = end_time - start_time

# print("Video saved at:", output_file_path)
print("Time taken to run the code:", execution_duration, "seconds")
# Out:
# /usr/local/lib/python3.10/dist-packages/imageai/Detection/__init__.py:255: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(self.__model_path, map_location=self.__device)
# FOR FRAME  1
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  2
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  3
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  4
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  5
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  6
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  7
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 77.31, 'box_points': [30, 648, 468, 1245]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  8
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 73.36, 'box_points': [32, 647, 468, 1245]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  9
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 77.7, 'box_points': [28, 649, 469, 1242]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  10
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 77.77, 'box_points': [25, 655, 480, 1242]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# SECOND :  1
# Array for the outputs of each frame  [[], [], [], [], [], [], [{'name': 'backpack', 'percentage_probability': 77.31, 'box_points': [30, 648, 468, 1245]}], [{'name': 'backpack', 'percentage_probability': 73.36, 'box_points': [32, 647, 468, 1245]}], [{'name': 'backpack', 'percentage_probability': 77.7, 'box_points': [28, 649, 469, 1242]}], [{'name': 'backpack', 'percentage_probability': 77.77, 'box_points': [25, 655, 480, 1242]}]]
# Array for output count for unique objects in each frame :  [{}, {}, {}, {}, {}, {}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}]
# Output average count for unique objects in the last second:  {'backpack': 0}
# ------------END OF A SECOND --------------
# FOR FRAME  11
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 84.76, 'box_points': [25, 659, 472, 1238]}, {'name': 'chair', 'percentage_probability': 83.41, 'box_points': [285, 382, 654, 914]}]
# Output count for unique objects :  {'backpack': 1, 'chair': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  12
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 72.14, 'box_points': [23, 646, 482, 1245]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  13
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 76.29, 'box_points': [25, 655, 480, 1242]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  14
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 69.69, 'box_points': [29, 664, 479, 1240]}, {'name': 'suitcase', 'percentage_probability': 75.27, 'box_points': [275, 377, 657, 911]}]
# Output count for unique objects :  {'backpack': 1, 'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  15
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 62.85, 'box_points': [26, 655, 492, 1246]}, {'name': 'chair', 'percentage_probability': 75.18, 'box_points': [279, 379, 654, 912]}]
# Output count for unique objects :  {'suitcase': 1, 'chair': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  16
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 78.09, 'box_points': [28, 662, 477, 1242]}, {'name': 'chair', 'percentage_probability': 76.85, 'box_points': [284, 380, 654, 907]}]
# Output count for unique objects :  {'backpack': 1, 'chair': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  17
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 76.88, 'box_points': [28, 659, 472, 1242]}, {'name': 'chair', 'percentage_probability': 82.28, 'box_points': [284, 365, 655, 921]}]
# Output count for unique objects :  {'backpack': 1, 'chair': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  18
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 79.98, 'box_points': [30, 658, 471, 1244]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  19
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 81.0, 'box_points': [28, 663, 466, 1241]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  20
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 76.9, 'box_points': [25, 662, 473, 1244]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# SECOND :  2
# Array for the outputs of each frame  [[{'name': 'backpack', 'percentage_probability': 84.76, 'box_points': [25, 659, 472, 1238]}, {'name': 'chair', 'percentage_probability': 83.41, 'box_points': [285, 382, 654, 914]}], [{'name': 'backpack', 'percentage_probability': 72.14, 'box_points': [23, 646, 482, 1245]}], [{'name': 'backpack', 'percentage_probability': 76.29, 'box_points': [25, 655, 480, 1242]}], [{'name': 'backpack', 'percentage_probability': 69.69, 'box_points': [29, 664, 479, 1240]}, {'name': 'suitcase', 'percentage_probability': 75.27, 'box_points': [275, 377, 657, 911]}], [{'name': 'suitcase', 'percentage_probability': 62.85, 'box_points': [26, 655, 492, 1246]}, {'name': 'chair', 'percentage_probability': 75.18, 'box_points': [279, 379, 654, 912]}], [{'name': 'backpack', 'percentage_probability': 78.09, 'box_points': [28, 662, 477, 1242]}, {'name': 'chair', 'percentage_probability': 76.85, 'box_points': [284, 380, 654, 907]}], [{'name': 'backpack', 'percentage_probability': 76.88, 'box_points': [28, 659, 472, 1242]}, {'name': 'chair', 'percentage_probability': 82.28, 'box_points': [284, 365, 655, 921]}], [{'name': 'backpack', 'percentage_probability': 79.98, 'box_points': [30, 658, 471, 1244]}], [{'name': 'backpack', 'percentage_probability': 81.0, 'box_points': [28, 663, 466, 1241]}], [{'name': 'backpack', 'percentage_probability': 76.9, 'box_points': [25, 662, 473, 1244]}]]
# Array for output count for unique objects in each frame :  [{'backpack': 1, 'chair': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1, 'suitcase': 1}, {'suitcase': 1, 'chair': 1}, {'backpack': 1, 'chair': 1}, {'backpack': 1, 'chair': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}]
# Output average count for unique objects in the last second:  {'backpack': 0, 'chair': 0, 'suitcase': 0}
# ------------END OF A SECOND --------------
# FOR FRAME  21
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 76.88, 'box_points': [23, 662, 480, 1244]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  22
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 65.27, 'box_points': [27, 664, 472, 1240]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  23
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 65.54, 'box_points': [17, 660, 489, 1242]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  24
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 77.3, 'box_points': [28, 655, 476, 1248]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  25
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 77.05, 'box_points': [28, 649, 478, 1248]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  26
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 81.75, 'box_points': [26, 654, 477, 1246]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  27
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 82.49, 'box_points': [26, 649, 482, 1250]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  28
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 83.19, 'box_points': [31, 646, 479, 1249]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  29
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 88.33, 'box_points': [27, 652, 475, 1247]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  30
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 90.16, 'box_points': [23, 647, 492, 1255]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# SECOND :  3
# Array for the outputs of each frame  [[{'name': 'backpack', 'percentage_probability': 76.88, 'box_points': [23, 662, 480, 1244]}], [{'name': 'suitcase', 'percentage_probability': 65.27, 'box_points': [27, 664, 472, 1240]}], [{'name': 'backpack', 'percentage_probability': 65.54, 'box_points': [17, 660, 489, 1242]}], [{'name': 'backpack', 'percentage_probability': 77.3, 'box_points': [28, 655, 476, 1248]}], [{'name': 'backpack', 'percentage_probability': 77.05, 'box_points': [28, 649, 478, 1248]}], [{'name': 'backpack', 'percentage_probability': 81.75, 'box_points': [26, 654, 477, 1246]}], [{'name': 'backpack', 'percentage_probability': 82.49, 'box_points': [26, 649, 482, 1250]}], [{'name': 'backpack', 'percentage_probability': 83.19, 'box_points': [31, 646, 479, 1249]}], [{'name': 'backpack', 'percentage_probability': 88.33, 'box_points': [27, 652, 475, 1247]}], [{'name': 'backpack', 'percentage_probability': 90.16, 'box_points': [23, 647, 492, 1255]}]]
# Array for output count for unique objects in each frame :  [{'backpack': 1}, {'suitcase': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}]
# Output average count for unique objects in the last second:  {'backpack': 0, 'suitcase': 0}
# ------------END OF A SECOND --------------
# FOR FRAME  31
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 82.23, 'box_points': [19, 637, 509, 1259]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  32
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 82.22, 'box_points': [33, 636, 490, 1262]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  33
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 84.47, 'box_points': [27, 640, 496, 1265]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  34
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 72.7, 'box_points': [28, 631, 493, 1275]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  35
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 70.15, 'box_points': [28, 630, 490, 1272]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  36
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 74.54, 'box_points': [26, 636, 485, 1266]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  37
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 65.85, 'box_points': [25, 625, 501, 1277]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  38
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 71.82, 'box_points': [24, 631, 500, 1275]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  39
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 84.45, 'box_points': [25, 630, 490, 1271]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  40
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 85.83, 'box_points': [30, 634, 479, 1270]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# SECOND :  4
# Array for the outputs of each frame  [[{'name': 'backpack', 'percentage_probability': 82.23, 'box_points': [19, 637, 509, 1259]}], [{'name': 'backpack', 'percentage_probability': 82.22, 'box_points': [33, 636, 490, 1262]}], [{'name': 'backpack', 'percentage_probability': 84.47, 'box_points': [27, 640, 496, 1265]}], [{'name': 'backpack', 'percentage_probability': 72.7, 'box_points': [28, 631, 493, 1275]}], [{'name': 'backpack', 'percentage_probability': 70.15, 'box_points': [28, 630, 490, 1272]}], [{'name': 'backpack', 'percentage_probability': 74.54, 'box_points': [26, 636, 485, 1266]}], [{'name': 'backpack', 'percentage_probability': 65.85, 'box_points': [25, 625, 501, 1277]}], [{'name': 'backpack', 'percentage_probability': 71.82, 'box_points': [24, 631, 500, 1275]}], [{'name': 'backpack', 'percentage_probability': 84.45, 'box_points': [25, 630, 490, 1271]}], [{'name': 'backpack', 'percentage_probability': 85.83, 'box_points': [30, 634, 479, 1270]}]]
# Array for output count for unique objects in each frame :  [{'backpack': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}]
# Output average count for unique objects in the last second:  {'backpack': 1}
# ------------END OF A SECOND --------------
# FOR FRAME  41
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 74.95, 'box_points': [33, 622, 483, 1280]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  42
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 78.74, 'box_points': [28, 621, 492, 1280]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  43
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 75.19, 'box_points': [31, 617, 495, 1280]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  44
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 73.03, 'box_points': [30, 630, 491, 1274]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  45
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 76.27, 'box_points': [29, 634, 488, 1272]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  46
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 78.56, 'box_points': [34, 631, 490, 1275]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  47
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 76.22, 'box_points': [28, 631, 489, 1272]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  48
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 72.42, 'box_points': [30, 629, 496, 1276]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  49
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 63.2, 'box_points': [30, 621, 505, 1280]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  50
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 60.33, 'box_points': [35, 616, 498, 1280]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# SECOND :  5
# Array for the outputs of each frame  [[{'name': 'backpack', 'percentage_probability': 74.95, 'box_points': [33, 622, 483, 1280]}], [{'name': 'backpack', 'percentage_probability': 78.74, 'box_points': [28, 621, 492, 1280]}], [{'name': 'backpack', 'percentage_probability': 75.19, 'box_points': [31, 617, 495, 1280]}], [{'name': 'backpack', 'percentage_probability': 73.03, 'box_points': [30, 630, 491, 1274]}], [{'name': 'backpack', 'percentage_probability': 76.27, 'box_points': [29, 634, 488, 1272]}], [{'name': 'backpack', 'percentage_probability': 78.56, 'box_points': [34, 631, 490, 1275]}], [{'name': 'backpack', 'percentage_probability': 76.22, 'box_points': [28, 631, 489, 1272]}], [{'name': 'backpack', 'percentage_probability': 72.42, 'box_points': [30, 629, 496, 1276]}], [{'name': 'backpack', 'percentage_probability': 63.2, 'box_points': [30, 621, 505, 1280]}], [{'name': 'suitcase', 'percentage_probability': 60.33, 'box_points': [35, 616, 498, 1280]}]]
# Array for output count for unique objects in each frame :  [{'backpack': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}, {'backpack': 1}, {'suitcase': 1}]
# Output average count for unique objects in the last second:  {'backpack': 0, 'suitcase': 0}
# ------------END OF A SECOND --------------
# FOR FRAME  51
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  52
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  53
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  54
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  55
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  56
# Output for each object :  [{'name': 'chair', 'percentage_probability': 77.3, 'box_points': [353, 367, 701, 938]}]
# Output count for unique objects :  {'chair': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  57
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  58
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  59
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 81.62, 'box_points': [25, 626, 518, 1275]}, {'name': 'suitcase', 'percentage_probability': 75.32, 'box_points': [352, 373, 698, 931]}]
# Output count for unique objects :  {'backpack': 1, 'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  60
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# SECOND :  6
# Array for the outputs of each frame  [[], [], [], [], [], [{'name': 'chair', 'percentage_probability': 77.3, 'box_points': [353, 367, 701, 938]}], [], [], [{'name': 'backpack', 'percentage_probability': 81.62, 'box_points': [25, 626, 518, 1275]}, {'name': 'suitcase', 'percentage_probability': 75.32, 'box_points': [352, 373, 698, 931]}], []]
# Array for output count for unique objects in each frame :  [{}, {}, {}, {}, {}, {'chair': 1}, {}, {}, {'backpack': 1, 'suitcase': 1}, {}]
# Output average count for unique objects in the last second:  {'chair': 0, 'backpack': 0, 'suitcase': 0}
# ------------END OF A SECOND --------------
# FOR FRAME  61
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 77.27, 'box_points': [23, 607, 517, 1280]}, {'name': 'chair', 'percentage_probability': 83.45, 'box_points': [355, 373, 699, 928]}]
# Output count for unique objects :  {'backpack': 1, 'chair': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  62
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 59.81, 'box_points': [21, 615, 528, 1280]}]
# Output count for unique objects :  {'backpack': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  63
# Output for each object :  [{'name': 'chair', 'percentage_probability': 89.62, 'box_points': [350, 368, 705, 926]}]
# Output count for unique objects :  {'chair': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  64
# Output for each object :  [{'name': 'chair', 'percentage_probability': 88.78, 'box_points': [353, 364, 702, 930]}]
# Output count for unique objects :  {'chair': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  65
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  66
# Output for each object :  [{'name': 'chair', 'percentage_probability': 82.9, 'box_points': [351, 353, 706, 925]}]
# Output count for unique objects :  {'chair': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  67
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  68
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  69
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  70
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# SECOND :  7
# Array for the outputs of each frame  [[{'name': 'backpack', 'percentage_probability': 77.27, 'box_points': [23, 607, 517, 1280]}, {'name': 'chair', 'percentage_probability': 83.45, 'box_points': [355, 373, 699, 928]}], [{'name': 'backpack', 'percentage_probability': 59.81, 'box_points': [21, 615, 528, 1280]}], [{'name': 'chair', 'percentage_probability': 89.62, 'box_points': [350, 368, 705, 926]}], [{'name': 'chair', 'percentage_probability': 88.78, 'box_points': [353, 364, 702, 930]}], [], [{'name': 'chair', 'percentage_probability': 82.9, 'box_points': [351, 353, 706, 925]}], [], [], [], []]
# Array for output count for unique objects in each frame :  [{'backpack': 1, 'chair': 1}, {'backpack': 1}, {'chair': 1}, {'chair': 1}, {}, {'chair': 1}, {}, {}, {}, {}]
# Output average count for unique objects in the last second:  {'backpack': 0, 'chair': 0}
# ------------END OF A SECOND --------------
# FOR FRAME  71
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  72
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  73
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  74
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  75
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  76
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  77
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  78
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  79
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  80
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# SECOND :  8
# Array for the outputs of each frame  [[], [], [], [], [], [], [], [], [], []]
# Array for output count for unique objects in each frame :  [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}]
# Output average count for unique objects in the last second:  {}
# ------------END OF A SECOND --------------
# FOR FRAME  81
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  82
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  83
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  84
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  85
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  86
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  87
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  88
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  89
# Output for each object :  [{'name': 'chair', 'percentage_probability': 41.44, 'box_points': [356, 313, 711, 781]}]
# Output count for unique objects :  {'chair': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  90
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# SECOND :  9
# Array for the outputs of each frame  [[], [], [], [], [], [], [], [], [{'name': 'chair', 'percentage_probability': 41.44, 'box_points': [356, 313, 711, 781]}], []]
# Array for output count for unique objects in each frame :  [{}, {}, {}, {}, {}, {}, {}, {}, {'chair': 1}, {}]
# Output average count for unique objects in the last second:  {'chair': 0}
# ------------END OF A SECOND --------------
# FOR FRAME  91
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  92
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  93
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  94
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  95
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 37.64, 'box_points': [354, 295, 720, 785]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  96
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  97
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  98
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 49.67, 'box_points': [358, 283, 713, 791]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  99
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 59.55, 'box_points': [361, 286, 709, 780]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  100
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# SECOND :  10
# Array for the outputs of each frame  [[], [], [], [], [{'name': 'suitcase', 'percentage_probability': 37.64, 'box_points': [354, 295, 720, 785]}], [], [], [{'name': 'suitcase', 'percentage_probability': 49.67, 'box_points': [358, 283, 713, 791]}], [{'name': 'suitcase', 'percentage_probability': 59.55, 'box_points': [361, 286, 709, 780]}], []]
# Array for output count for unique objects in each frame :  [{}, {}, {}, {}, {'suitcase': 1}, {}, {}, {'suitcase': 1}, {'suitcase': 1}, {}]
# Output average count for unique objects in the last second:  {'suitcase': 0}
# ------------END OF A SECOND --------------
# FOR FRAME  101
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  102
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  103
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  104
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  105
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  106
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  107
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  108
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  109
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  110
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# SECOND :  11
# Array for the outputs of each frame  [[], [], [], [], [], [], [], [], [], []]
# Array for output count for unique objects in each frame :  [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}]
# Output average count for unique objects in the last second:  {}
# ------------END OF A SECOND --------------
# FOR FRAME  111
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  112
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  113
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  114
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  115
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  116
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  117
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  118
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  119
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  120
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# SECOND :  12
# Array for the outputs of each frame  [[], [], [], [], [], [], [], [], [], []]
# Array for output count for unique objects in each frame :  [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}]
# Output average count for unique objects in the last second:  {}
# ------------END OF A SECOND --------------
# FOR FRAME  121
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  122
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  123
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  124
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  125
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  126
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  127
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  128
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  129
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  130
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# SECOND :  13
# Array for the outputs of each frame  [[], [], [], [], [], [], [], [], [], []]
# Array for output count for unique objects in each frame :  [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}]
# Output average count for unique objects in the last second:  {}
# ------------END OF A SECOND --------------
# FOR FRAME  131
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  132
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  133
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  134
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  135
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  136
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  137
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  138
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  139
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  140
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# SECOND :  14
# Array for the outputs of each frame  [[], [], [], [], [], [], [], [], [], []]
# Array for output count for unique objects in each frame :  [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}]
# Output average count for unique objects in the last second:  {}
# ------------END OF A SECOND --------------
# FOR FRAME  141
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  142
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  143
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  144
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  145
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  146
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  147
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  148
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  149
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  150
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# SECOND :  15
# Array for the outputs of each frame  [[], [], [], [], [], [], [], [], [], []]
# Array for output count for unique objects in each frame :  [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}]
# Output average count for unique objects in the last second:  {}
# ------------END OF A SECOND --------------
# FOR FRAME  151
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  152
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 80.86, 'box_points': [13, 545, 498, 1270]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  153
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 79.82, 'box_points': [8, 536, 500, 1278]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  154
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 82.57, 'box_points': [6, 535, 502, 1277]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  155
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 84.35, 'box_points': [8, 539, 508, 1274]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  156
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  157
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 71.35, 'box_points': [22, 535, 507, 1275]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  158
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 82.41, 'box_points': [8, 543, 511, 1275]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  159
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 85.85, 'box_points': [11, 548, 501, 1272]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  160
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 90.1, 'box_points': [9, 555, 503, 1261]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# SECOND :  16
# Array for the outputs of each frame  [[], [{'name': 'suitcase', 'percentage_probability': 80.86, 'box_points': [13, 545, 498, 1270]}], [{'name': 'suitcase', 'percentage_probability': 79.82, 'box_points': [8, 536, 500, 1278]}], [{'name': 'suitcase', 'percentage_probability': 82.57, 'box_points': [6, 535, 502, 1277]}], [{'name': 'suitcase', 'percentage_probability': 84.35, 'box_points': [8, 539, 508, 1274]}], [], [{'name': 'suitcase', 'percentage_probability': 71.35, 'box_points': [22, 535, 507, 1275]}], [{'name': 'suitcase', 'percentage_probability': 82.41, 'box_points': [8, 543, 511, 1275]}], [{'name': 'suitcase', 'percentage_probability': 85.85, 'box_points': [11, 548, 501, 1272]}], [{'name': 'suitcase', 'percentage_probability': 90.1, 'box_points': [9, 555, 503, 1261]}]]
# Array for output count for unique objects in each frame :  [{}, {'suitcase': 1}, {'suitcase': 1}, {'suitcase': 1}, {'suitcase': 1}, {}, {'suitcase': 1}, {'suitcase': 1}, {'suitcase': 1}, {'suitcase': 1}]
# Output average count for unique objects in the last second:  {'suitcase': 0}
# ------------END OF A SECOND --------------
# FOR FRAME  161
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 85.68, 'box_points': [9, 542, 502, 1273]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  162
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 87.9, 'box_points': [3, 550, 507, 1267]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  163
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 92.52, 'box_points': [10, 548, 508, 1270]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  164
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 96.53, 'box_points': [13, 549, 511, 1268]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  165
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 90.33, 'box_points': [6, 546, 507, 1275]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  166
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 86.63, 'box_points': [3, 541, 511, 1277]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  167
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 90.29, 'box_points': [4, 549, 516, 1271]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  168
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 90.61, 'box_points': [5, 552, 518, 1270]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  169
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 90.24, 'box_points': [6, 558, 520, 1267]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  170
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# SECOND :  17
# Array for the outputs of each frame  [[{'name': 'suitcase', 'percentage_probability': 85.68, 'box_points': [9, 542, 502, 1273]}], [{'name': 'suitcase', 'percentage_probability': 87.9, 'box_points': [3, 550, 507, 1267]}], [{'name': 'suitcase', 'percentage_probability': 92.52, 'box_points': [10, 548, 508, 1270]}], [{'name': 'suitcase', 'percentage_probability': 96.53, 'box_points': [13, 549, 511, 1268]}], [{'name': 'suitcase', 'percentage_probability': 90.33, 'box_points': [6, 546, 507, 1275]}], [{'name': 'suitcase', 'percentage_probability': 86.63, 'box_points': [3, 541, 511, 1277]}], [{'name': 'suitcase', 'percentage_probability': 90.29, 'box_points': [4, 549, 516, 1271]}], [{'name': 'suitcase', 'percentage_probability': 90.61, 'box_points': [5, 552, 518, 1270]}], [{'name': 'suitcase', 'percentage_probability': 90.24, 'box_points': [6, 558, 520, 1267]}], []]
# Array for output count for unique objects in each frame :  [{'suitcase': 1}, {'suitcase': 1}, {'suitcase': 1}, {'suitcase': 1}, {'suitcase': 1}, {'suitcase': 1}, {'suitcase': 1}, {'suitcase': 1}, {'suitcase': 1}, {}]
# Output average count for unique objects in the last second:  {'suitcase': 0}
# ------------END OF A SECOND --------------
# FOR FRAME  171
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 84.87, 'box_points': [6, 551, 517, 1270]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  172
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 91.1, 'box_points': [4, 554, 517, 1267]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  173
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 88.14, 'box_points': [7, 549, 516, 1272]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  174
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 89.43, 'box_points': [8, 548, 519, 1273]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  175
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 91.05, 'box_points': [6, 553, 519, 1269]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  176
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 88.17, 'box_points': [5, 555, 511, 1264]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  177
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 86.06, 'box_points': [6, 550, 513, 1268]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  178
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 92.87, 'box_points': [11, 557, 517, 1262]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  179
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 86.26, 'box_points': [13, 543, 507, 1273]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  180
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 73.27, 'box_points': [5, 543, 509, 1273]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# SECOND :  18
# Array for the outputs of each frame  [[{'name': 'suitcase', 'percentage_probability': 84.87, 'box_points': [6, 551, 517, 1270]}], [{'name': 'suitcase', 'percentage_probability': 91.1, 'box_points': [4, 554, 517, 1267]}], [{'name': 'suitcase', 'percentage_probability': 88.14, 'box_points': [7, 549, 516, 1272]}], [{'name': 'suitcase', 'percentage_probability': 89.43, 'box_points': [8, 548, 519, 1273]}], [{'name': 'suitcase', 'percentage_probability': 91.05, 'box_points': [6, 553, 519, 1269]}], [{'name': 'suitcase', 'percentage_probability': 88.17, 'box_points': [5, 555, 511, 1264]}], [{'name': 'suitcase', 'percentage_probability': 86.06, 'box_points': [6, 550, 513, 1268]}], [{'name': 'suitcase', 'percentage_probability': 92.87, 'box_points': [11, 557, 517, 1262]}], [{'name': 'suitcase', 'percentage_probability': 86.26, 'box_points': [13, 543, 507, 1273]}], [{'name': 'suitcase', 'percentage_probability': 73.27, 'box_points': [5, 543, 509, 1273]}]]
# Array for output count for unique objects in each frame :  [{'suitcase': 1}, {'suitcase': 1}, {'suitcase': 1}, {'suitcase': 1}, {'suitcase': 1}, {'suitcase': 1}, {'suitcase': 1}, {'suitcase': 1}, {'suitcase': 1}, {'suitcase': 1}]
# Output average count for unique objects in the last second:  {'suitcase': 1}
# ------------END OF A SECOND --------------
# FOR FRAME  181
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 84.67, 'box_points': [12, 547, 501, 1271]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  182
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  183
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 65.9, 'box_points': [6, 532, 506, 1280]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  184
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  185
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 83.32, 'box_points': [11, 550, 498, 1274]}]
# Output count for unique objects :  {'suitcase': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  186
# Output for each object :  [{'name': 'suitcase', 'percentage_probability': 63.83, 'box_points': [11, 559, 487, 1272]}]
# Output count for unique objects :  {'suitcase': 1}
# ...
# Array for output count for unique objects in each frame :  [{'laptop': 1}, {'laptop': 1}, {'laptop': 1}, {'laptop': 1}, {'laptop': 1}, {'laptop': 1}, {'laptop': 1, 'keyboard': 1}, {'laptop': 1}, {'laptop': 1}, {'laptop': 1}]
# Output average count for unique objects in the last second:  {'laptop': 1, 'keyboard': 0}
# ------------END OF A SECOND --------------
# FOR FRAME  931
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 91.11, 'box_points': [40, 348, 720, 1280]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  932
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 94.42, 'box_points': [14, 200, 720, 1280]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  933
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 92.86, 'box_points': [18, 214, 720, 1280]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  934
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  935
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 93.66, 'box_points': [13, 206, 720, 1280]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  936
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  937
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 95.0, 'box_points': [11, 182, 720, 1280]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  938
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  939
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 92.27, 'box_points': [13, 154, 720, 1280]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  940
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 90.06, 'box_points': [23, 178, 720, 1280]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# SECOND :  94
# Array for the outputs of each frame  [[{'name': 'laptop', 'percentage_probability': 91.11, 'box_points': [40, 348, 720, 1280]}], [{'name': 'laptop', 'percentage_probability': 94.42, 'box_points': [14, 200, 720, 1280]}], [{'name': 'laptop', 'percentage_probability': 92.86, 'box_points': [18, 214, 720, 1280]}], [], [{'name': 'laptop', 'percentage_probability': 93.66, 'box_points': [13, 206, 720, 1280]}], [], [{'name': 'laptop', 'percentage_probability': 95.0, 'box_points': [11, 182, 720, 1280]}], [], [{'name': 'laptop', 'percentage_probability': 92.27, 'box_points': [13, 154, 720, 1280]}], [{'name': 'laptop', 'percentage_probability': 90.06, 'box_points': [23, 178, 720, 1280]}]]
# Array for output count for unique objects in each frame :  [{'laptop': 1}, {'laptop': 1}, {'laptop': 1}, {}, {'laptop': 1}, {}, {'laptop': 1}, {}, {'laptop': 1}, {'laptop': 1}]
# Output average count for unique objects in the last second:  {'laptop': 0}
# ------------END OF A SECOND --------------
# FOR FRAME  941
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 87.01, 'box_points': [25, 177, 720, 1280]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  942
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 93.83, 'box_points': [29, 143, 720, 1280]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  943
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 89.28, 'box_points': [19, 191, 720, 1280]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  944
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 90.15, 'box_points': [25, 207, 720, 1266]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  945
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 94.77, 'box_points': [45, 213, 720, 1265]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  946
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 94.97, 'box_points': [57, 202, 720, 1275]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  947
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 93.13, 'box_points': [54, 215, 718, 1260]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  948
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 91.38, 'box_points': [44, 195, 720, 1277]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  949
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 77.67, 'box_points': [36, 175, 720, 1280]}, {'name': 'keyboard', 'percentage_probability': 80.83, 'box_points': [75, 614, 719, 1247]}]
# Output count for unique objects :  {'laptop': 1, 'keyboard': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  950
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 84.98, 'box_points': [42, 184, 720, 1280]}, {'name': 'keyboard', 'percentage_probability': 70.95, 'box_points': [82, 611, 708, 1240]}]
# Output count for unique objects :  {'laptop': 1, 'keyboard': 1}
# ------------END OF A FRAME --------------
# SECOND :  95
# Array for the outputs of each frame  [[{'name': 'laptop', 'percentage_probability': 87.01, 'box_points': [25, 177, 720, 1280]}], [{'name': 'laptop', 'percentage_probability': 93.83, 'box_points': [29, 143, 720, 1280]}], [{'name': 'laptop', 'percentage_probability': 89.28, 'box_points': [19, 191, 720, 1280]}], [{'name': 'laptop', 'percentage_probability': 90.15, 'box_points': [25, 207, 720, 1266]}], [{'name': 'laptop', 'percentage_probability': 94.77, 'box_points': [45, 213, 720, 1265]}], [{'name': 'laptop', 'percentage_probability': 94.97, 'box_points': [57, 202, 720, 1275]}], [{'name': 'laptop', 'percentage_probability': 93.13, 'box_points': [54, 215, 718, 1260]}], [{'name': 'laptop', 'percentage_probability': 91.38, 'box_points': [44, 195, 720, 1277]}], [{'name': 'laptop', 'percentage_probability': 77.67, 'box_points': [36, 175, 720, 1280]}, {'name': 'keyboard', 'percentage_probability': 80.83, 'box_points': [75, 614, 719, 1247]}], [{'name': 'laptop', 'percentage_probability': 84.98, 'box_points': [42, 184, 720, 1280]}, {'name': 'keyboard', 'percentage_probability': 70.95, 'box_points': [82, 611, 708, 1240]}]]
# Array for output count for unique objects in each frame :  [{'laptop': 1}, {'laptop': 1}, {'laptop': 1}, {'laptop': 1}, {'laptop': 1}, {'laptop': 1}, {'laptop': 1}, {'laptop': 1}, {'laptop': 1, 'keyboard': 1}, {'laptop': 1, 'keyboard': 1}]
# Output average count for unique objects in the last second:  {'laptop': 1, 'keyboard': 0}
# ------------END OF A SECOND --------------
# FOR FRAME  951
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 88.16, 'box_points': [29, 169, 720, 1280]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  952
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 90.68, 'box_points': [23, 116, 720, 1197]}, {'name': 'keyboard', 'percentage_probability': 90.47, 'box_points': [94, 590, 701, 1236]}]
# Output count for unique objects :  {'laptop': 1, 'keyboard': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  953
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 90.03, 'box_points': [0, 106, 720, 1186]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  954
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 94.6, 'box_points': [22, 95, 720, 1189]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  955
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 88.89, 'box_points': [14, 101, 720, 1186]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  956
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 83.82, 'box_points': [35, 97, 720, 1195]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  957
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 94.22, 'box_points': [27, 106, 720, 1177]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  958
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 92.74, 'box_points': [25, 110, 720, 1172]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  959
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 94.43, 'box_points': [25, 114, 720, 1173]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  960
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 94.92, 'box_points': [51, 126, 720, 1149]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# SECOND :  96
# Array for the outputs of each frame  [[{'name': 'laptop', 'percentage_probability': 88.16, 'box_points': [29, 169, 720, 1280]}], [{'name': 'laptop', 'percentage_probability': 90.68, 'box_points': [23, 116, 720, 1197]}, {'name': 'keyboard', 'percentage_probability': 90.47, 'box_points': [94, 590, 701, 1236]}], [{'name': 'laptop', 'percentage_probability': 90.03, 'box_points': [0, 106, 720, 1186]}], [{'name': 'laptop', 'percentage_probability': 94.6, 'box_points': [22, 95, 720, 1189]}], [{'name': 'laptop', 'percentage_probability': 88.89, 'box_points': [14, 101, 720, 1186]}], [{'name': 'laptop', 'percentage_probability': 83.82, 'box_points': [35, 97, 720, 1195]}], [{'name': 'laptop', 'percentage_probability': 94.22, 'box_points': [27, 106, 720, 1177]}], [{'name': 'laptop', 'percentage_probability': 92.74, 'box_points': [25, 110, 720, 1172]}], [{'name': 'laptop', 'percentage_probability': 94.43, 'box_points': [25, 114, 720, 1173]}], [{'name': 'laptop', 'percentage_probability': 94.92, 'box_points': [51, 126, 720, 1149]}]]
# Array for output count for unique objects in each frame :  [{'laptop': 1}, {'laptop': 1, 'keyboard': 1}, {'laptop': 1}, {'laptop': 1}, {'laptop': 1}, {'laptop': 1}, {'laptop': 1}, {'laptop': 1}, {'laptop': 1}, {'laptop': 1}]
# Output average count for unique objects in the last second:  {'laptop': 1, 'keyboard': 0}
# ------------END OF A SECOND --------------
# FOR FRAME  961
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 96.07, 'box_points': [52, 101, 720, 1187]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  962
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 97.35, 'box_points': [57, 128, 720, 1154]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  963
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 96.53, 'box_points': [56, 127, 720, 1157]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  964
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 94.39, 'box_points': [50, 134, 720, 1152]}, {'name': 'keyboard', 'percentage_probability': 88.64, 'box_points': [91, 526, 701, 1156]}]
# Output count for unique objects :  {'laptop': 1, 'keyboard': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  965
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 93.21, 'box_points': [27, 138, 720, 1155]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  966
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 96.22, 'box_points': [39, 110, 720, 1166]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  967
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 92.16, 'box_points': [26, 102, 720, 1177]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  968
# Output for each object :  []
# Output count for unique objects :  {}
# ------------END OF A FRAME --------------
# FOR FRAME  969
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 95.91, 'box_points': [1, 21, 720, 1096]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  970
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 94.71, 'box_points': [1, 89, 720, 1180]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# SECOND :  97
# Array for the outputs of each frame  [[{'name': 'laptop', 'percentage_probability': 96.07, 'box_points': [52, 101, 720, 1187]}], [{'name': 'laptop', 'percentage_probability': 97.35, 'box_points': [57, 128, 720, 1154]}], [{'name': 'laptop', 'percentage_probability': 96.53, 'box_points': [56, 127, 720, 1157]}], [{'name': 'laptop', 'percentage_probability': 94.39, 'box_points': [50, 134, 720, 1152]}, {'name': 'keyboard', 'percentage_probability': 88.64, 'box_points': [91, 526, 701, 1156]}], [{'name': 'laptop', 'percentage_probability': 93.21, 'box_points': [27, 138, 720, 1155]}], [{'name': 'laptop', 'percentage_probability': 96.22, 'box_points': [39, 110, 720, 1166]}], [{'name': 'laptop', 'percentage_probability': 92.16, 'box_points': [26, 102, 720, 1177]}], [], [{'name': 'laptop', 'percentage_probability': 95.91, 'box_points': [1, 21, 720, 1096]}], [{'name': 'laptop', 'percentage_probability': 94.71, 'box_points': [1, 89, 720, 1180]}]]
# Array for output count for unique objects in each frame :  [{'laptop': 1}, {'laptop': 1}, {'laptop': 1}, {'laptop': 1, 'keyboard': 1}, {'laptop': 1}, {'laptop': 1}, {'laptop': 1}, {}, {'laptop': 1}, {'laptop': 1}]
# Output average count for unique objects in the last second:  {'laptop': 0, 'keyboard': 0}
# ------------END OF A SECOND --------------
# FOR FRAME  971
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 94.14, 'box_points': [3, 107, 720, 1157]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  972
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 97.84, 'box_points': [0, 40, 720, 1076]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  973
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 97.57, 'box_points': [4, 29, 720, 1092]}]
# Output count for unique objects :  {'laptop': 1}
# ------------END OF A FRAME --------------
# FOR FRAME  974
# Output for each object :  [{'name': 'laptop', 'percentage_probability': 97.76, 'box_points': [8, 43, 720, 1067]}, {'name': 'keyboard', 'percentage_probability': 86.43, 'box_points': [62, 494, 710, 1133]}]
# Output count for unique objects :  {'laptop': 1, 'keyboard': 1}
# ------------END OF A FRAME --------------
# Time taken to run the code: 214.31085062026978 seconds
